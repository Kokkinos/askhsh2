# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image

img=np.array(Image.open('trikoupi6.png'))

a = [10,40,80,100,120,150,190,210,240]

image = np.copy(img)
rows,cols = image.shape
plt.imshow(image,cmap="gray")
plt.show()
for i1 in range(0,9):
    
    for i in range(0,rows):
        for j in range(0,cols):
            if  (image[i][j]> a[i1]):
                image[i][j] = 255
            else:
                image[i][j] = 0
    print(a[i1]) 
    plt.imshow(image,cmap="gray")
    plt.show()
    image = np.copy(img)
# Out:
# 10
# 40
# 80
# 100
# 120
# 150
# 190
# 210
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-6eddf0e7e9a0> in <module>()
#      15
#      16     for i in range(0,rows):
# ---> 17         for j in range(0,cols):
#      18             if  (image[i][j]> a[i1]):
#      19                 image[i][j] = 255
#
# KeyboardInterrupt:
